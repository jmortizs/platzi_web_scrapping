# %%
import requests
import base64
import pandas as pd
from client_token import client_token

# %%
base_url = 'https://api.spotify.com/v1'
artist_id = '7Ln80lUS6He07XvHI8qqHH'
url = f'{base_url}/artists/{artist_id}'

# %%
url
# Out:
# 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH'

# %%
token_url = 'https://accounts.spotify.com/api/token'

# %%
params = {'grant_type': 'client_credentials'}
headers = {'Authorization': f'Basic {client_token}' }

# %%
r = requests.post(token_url, data=params, headers=headers)

# %%
r.status_code
# Out:
# 200

# %%
access_token = r.json()['access_token']

# %%
header= {'Authorization': f'Bearer {access_token}'}

# %%
r = requests.get(url, headers=header)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#  'followers': {'href': None, 'total': 12178887},
#  'genres': ['garage rock',
#   'modern rock',
#   'permanent wave',
#   'rock',
#   'sheffield indie'],
#  'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#  'id': '7Ln80lUS6He07XvHI8qqHH',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb39f37a34b404169fdca52dc8',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab6761610000517439f37a34b404169fdca52dc8',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f17839f37a34b404169fdca52dc8',
#    'width': 160}],
#  'name': 'Arctic Monkeys',
#  'popularity': 87,
#  'type': 'artist',
#  'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}

# %%
search_url = 'https://api.spotify.com/v1/search'

# %%
search_params = {'q':'Queen', 'type':'artist', 'market':'CO'}

# %%
search = requests.get(search_url, headers=header, params=search_params)

# %%
search.status_code
# Out:
# 200

# %%
search.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Queen&type=artist&market=CO&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#     'followers': {'href': None, 'total': 35360491},
#     'genres': ['classic rock', 'glam rock', 'rock'],
#     'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#     'id': '1dfeR4HaWDbWqFHLkxsg1d',
#     'images': [{'height': 806,
#       'url': 'https://i.scdn.co/image/b040846ceba13c3e9c125d68389491094e7f2982',
#       'width': 999},
#      {'height': 516,
#       'url': 'https://i.scdn.co/image/af2b8e57f6d7b5d43a616bd1e27ba552cd8bfd42',
#       'width': 640},
#      {'height': 161,
#       'url': 'https://i.scdn.co/image/c06971e9ff81696699b829484e3be165f4e64368',
#       'width': 200},
#      {'height': 52,
#       'url': 'https://i.scdn.co/image/6dd0ffd270903d1884edf9058c49f58b03db893d',
#       'width': 64}],
#     'name': 'Queen',
#     'popularity': 90,
#     'type': 'artist',
#     'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4pejUc4iciQfgdX6OKulQn'},
#     'followers': {'href': None, 'total': 2711924},
#     'genres': ['alternative metal',
#      'alternative rock',
#      'blues rock',
#      'modern rock',
#      'nu metal',
#      'palm desert scene',
#      'rock',
#      'stoner metal',
#      'stoner rock'],
#     'href': 'https://api.spotify.com/v1/artists/4pejUc4iciQfgdX6OKulQn',
#     'id': '4pejUc4iciQfgdX6OKulQn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebc194721f2ca5433bc78b0e74',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174c194721f2ca5433bc78b0e74',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178c194721f2ca5433bc78b0e74',
#       'width': 160}],
#     'name': 'Queens of the Stone Age',
#     'popularity': 74,
#     'type': 'artist',
#     'uri': 'spotify:artist:4pejUc4iciQfgdX6OKulQn'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6p2442ymrT9lZEuCZJdYcH'},
#     'followers': {'href': None, 'total': 1393043},
#     'genres': ['latin',
#      'latin hip hop',
#      'rap latina',
#      'reggaeton',
#      'trap latino',
#      'tropical'],
#     'href': 'https://api.spotify.com/v1/artists/6p2442ymrT9lZEuCZJdYcH',
#     'id': '6p2442ymrT9lZEuCZJdYcH',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb1ca96faf66db5240cc6def90',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051741ca96faf66db5240cc6def90',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1781ca96faf66db5240cc6def90',
#       'width': 160}],
#     'name': 'Ivy Queen',
#     'popularity': 71,
#     'type': 'artist',
#     'uri': 'spotify:artist:6p2442ymrT9lZEuCZJdYcH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#     'followers': {'href': None, 'total': 28020911},
#     'genres': ['dance pop', 'pop', 'post-teen pop', 'r&b'],
#     'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#     'id': '6vWDO969PvNqNYHIOW5v0m',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebd3d058be8485c8583703b6d2',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174d3d058be8485c8583703b6d2',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178d3d058be8485c8583703b6d2',
#       'width': 160}],
#     'name': 'Beyoncé',
#     'popularity': 88,
#     'type': 'artist',
#     'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2OgUPVlWYgGBGMefZgGvCO'},
#     'followers': {'href': None, 'total': 461983},
#     'genres': ['album rock',
#      'glam metal',
#      'hard rock',
#      'metal',
#      'progressive metal',
#      'rock',
#      'us power metal'],
#     'href': 'https://api.spotify.com/v1/artists/2OgUPVlWYgGBGMefZgGvCO',
#     'id': '2OgUPVlWYgGBGMefZgGvCO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebf765584aca5c90004d25c1e6',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174f765584aca5c90004d25c1e6',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178f765584aca5c90004d25c1e6',
#       'width': 160}],
#     'name': 'Queensrÿche',
#     'popularity': 60,
#     'type': 'artist',
#     'uri': 'spotify:artist:2OgUPVlWYgGBGMefZgGvCO'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0VbIlorLz3I5SEtIsc5vAr'},
#     'followers': {'href': None, 'total': 22196},
#     'genres': ['hip pop', 'lgbtq+ hip hop'],
#     'href': 'https://api.spotify.com/v1/artists/0VbIlorLz3I5SEtIsc5vAr',
#     'id': '0VbIlorLz3I5SEtIsc5vAr',
#     'images': [{'height': 997,
#       'url': 'https://i.scdn.co/image/ff4eabfc6691a25a8b43782e80a0ba0781f09a68',
#       'width': 1000},
#      {'height': 638,
#       'url': 'https://i.scdn.co/image/0a079ee27bb8e170fc2794fcdcffb0524b170d55',
#       'width': 640},
#      {'height': 199,
#       'url': 'https://i.scdn.co/image/e987de87ded3c2d69167fb8ac4b09e11cdea2fa1',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/1cfb64008f4c1308fac4381b262a153d5c944ee3',
#       'width': 64}],
#     'name': 'Queen Pen',
#     'popularity': 64,
#     'type': 'artist',
#     'uri': 'spotify:artist:0VbIlorLz3I5SEtIsc5vAr'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3nViOFa3kZW8OMSNOzwr98'},
#     'followers': {'href': None, 'total': 1913172},
#     'genres': ['dance pop',
#      'pop',
#      'pop r&b',
#      'pop rap',
#      'r&b',
#      'urban contemporary'],
#     'href': 'https://api.spotify.com/v1/artists/3nViOFa3kZW8OMSNOzwr98',
#     'id': '3nViOFa3kZW8OMSNOzwr98',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb828ef6ab43579ebd8d4570f4',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174828ef6ab43579ebd8d4570f4',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178828ef6ab43579ebd8d4570f4',
#       'width': 160}],
#     'name': 'Queen Naija',
#     'popularity': 70,
#     'type': 'artist',
#     'uri': 'spotify:artist:3nViOFa3kZW8OMSNOzwr98'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5m7wCUhYhBh7A3A3YMxrbt'},
#     'followers': {'href': None, 'total': 131222},
#     'genres': ['conscious hip hop',
#      'east coast hip hop',
#      'golden age hip hop',
#      'hip hop',
#      'hip pop',
#      'new jersey rap'],
#     'href': 'https://api.spotify.com/v1/artists/5m7wCUhYhBh7A3A3YMxrbt',
#     'id': '5m7wCUhYhBh7A3A3YMxrbt',
#     'images': [{'height': 980,
#       'url': 'https://i.scdn.co/image/8f0b1267ee4a84e260991c25d136ed4be13a8cbe',
#       'width': 1000},
#      {'height': 627,
#       'url': 'https://i.scdn.co/image/bd0d30004390383f4f272f4735386c851171bdb4',
#       'width': 640},
#      {'height': 196,
#       'url': 'https://i.scdn.co/image/014595f259c417b2ee3bd7164f61f21b0e4c3cd4',
#       'width': 200},
#      {'height': 63,
#       'url': 'https://i.scdn.co/image/280a4d9a38af33c661bcb1be9bbd00091850f5df',
#       'width': 64}],
#     'name': 'Queen Latifah',
#     'popularity': 60,
#     'type': 'artist',
#     'uri': 'spotify:artist:5m7wCUhYhBh7A3A3YMxrbt'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5LFWp4p0pMURif2d7z3ijQ'},
#     'followers': {'href': None, 'total': 9845},
#     'genres': ['afropop', 'south african jazz'],
#     'href': 'https://api.spotify.com/v1/artists/5LFWp4p0pMURif2d7z3ijQ',
#     'id': '5LFWp4p0pMURif2d7z3ijQ',
#     'images': [{'height': 1272,
#       'url': 'https://i.scdn.co/image/540439d090fdbbcf77120d0179bfe142401c80e7',
#       'width': 1000},
#      {'height': 814,
#       'url': 'https://i.scdn.co/image/33c502e4e285559b39a1bb67e26a6ffb47f67743',
#       'width': 640},
#      {'height': 254,
#       'url': 'https://i.scdn.co/image/ed5dcf404581eb92849179676e6a647b831e636a',
#       'width': 200},
#      {'height': 81,
#       'url': 'https://i.scdn.co/image/05d8f5c2bbd4b4b739226b7d0de9a6449f58866e',
#       'width': 64}],
#     'name': 'Mahlathini & The Mahotella Queens',
#     'popularity': 26,
#     'type': 'artist',
#     'uri': 'spotify:artist:5LFWp4p0pMURif2d7z3ijQ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6whFEcaV75AmQMiwlfaxvc'},
#     'followers': {'href': None, 'total': 184267},
#     'genres': ['anime rock', 'dance rock', 'j-pop', 'j-rock'],
#     'href': 'https://api.spotify.com/v1/artists/6whFEcaV75AmQMiwlfaxvc',
#     'id': '6whFEcaV75AmQMiwlfaxvc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb3b8f8e587f4e53154e1624ca',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051743b8f8e587f4e53154e1624ca',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1783b8f8e587f4e53154e1624ca',
#       'width': 160}],
#     'name': 'QUEEN BEE',
#     'popularity': 57,
#     'type': 'artist',
#     'uri': 'spotify:artist:6whFEcaV75AmQMiwlfaxvc'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/04vj3iPUiVh5melWr0w3xT'},
#     'followers': {'href': None, 'total': 580685},
#     'genres': ['art pop',
#      'electro-pop francais',
#      'electropop',
#      'metropopolis',
#      'shimmer pop'],
#     'href': 'https://api.spotify.com/v1/artists/04vj3iPUiVh5melWr0w3xT',
#     'id': '04vj3iPUiVh5melWr0w3xT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eba052b692f1df0aed70f59366',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174a052b692f1df0aed70f59366',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178a052b692f1df0aed70f59366',
#       'width': 160}],
#     'name': 'Christine and the Queens',
#     'popularity': 64,
#     'type': 'artist',
#     'uri': 'spotify:artist:04vj3iPUiVh5melWr0w3xT'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5FQWaF32sJ8rXb8aPcj2VI'},
#     'followers': {'href': None, 'total': 16012},
#     'genres': ['korean trap'],
#     'href': 'https://api.spotify.com/v1/artists/5FQWaF32sJ8rXb8aPcj2VI',
#     'id': '5FQWaF32sJ8rXb8aPcj2VI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d69611a69fe77b51a0c44cbe',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d69611a69fe77b51a0c44cbe',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d69611a69fe77b51a0c44cbe',
#       'width': 64}],
#     'name': 'Queen WA$ABII',
#     'popularity': 48,
#     'type': 'artist',
#     'uri': 'spotify:artist:5FQWaF32sJ8rXb8aPcj2VI'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5SK75gxwqKq5Zc1mdLfwv9'},
#     'followers': {'href': None, 'total': 87378},
#     'genres': ['dancehall',
#      'lovers rock',
#      'modern reggae',
#      'reggae fusion',
#      'roots reggae'],
#     'href': 'https://api.spotify.com/v1/artists/5SK75gxwqKq5Zc1mdLfwv9',
#     'id': '5SK75gxwqKq5Zc1mdLfwv9',
#     'images': [{'height': 1000,
#       'url': 'https://i.scdn.co/image/d3a5325327534e042312622ea7b955ba45800260',
#       'width': 1000},
#      {'height': 640,
#       'url': 'https://i.scdn.co/image/087d849a742d51b68e5bc53612a95423b16107ae',
#       'width': 640},
#      {'height': 200,
#       'url': 'https://i.scdn.co/image/597cc9337e88dffbce7c449dab2ebed8be0337a9',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/a845be9f159f3d2b5a728ab5c58549c26ec5c361',
#       'width': 64}],
#     'name': 'Queen Ifrica',
#     'popularity': 45,
#     'type': 'artist',
#     'uri': 'spotify:artist:5SK75gxwqKq5Zc1mdLfwv9'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/23fdfybq6v6zyJu7MUkB2Y'},
#     'followers': {'href': None, 'total': 1},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/23fdfybq6v6zyJu7MUkB2Y',
#     'id': '23fdfybq6v6zyJu7MUkB2Y',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c4ba21e29d19f408cc33b32d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c4ba21e29d19f408cc33b32d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c4ba21e29d19f408cc33b32d',
#       'width': 64}],
#     'name': 'Queendoom',
#     'popularity': 31,
#     'type': 'artist',
#     'uri': 'spotify:artist:23fdfybq6v6zyJu7MUkB2Y'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3638lzuFPAUR1hBQG4KFKS'},
#     'followers': {'href': None, 'total': 129},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3638lzuFPAUR1hBQG4KFKS',
#     'id': '3638lzuFPAUR1hBQG4KFKS',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebf9f62f5ce3283e29e91a3f3e',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174f9f62f5ce3283e29e91a3f3e',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178f9f62f5ce3283e29e91a3f3e',
#       'width': 160}],
#     'name': 'Crazy Queen Nay',
#     'popularity': 27,
#     'type': 'artist',
#     'uri': 'spotify:artist:3638lzuFPAUR1hBQG4KFKS'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0gHGRnDOmtiVyAE4v5nlZf'},
#     'followers': {'href': None, 'total': 2},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0gHGRnDOmtiVyAE4v5nlZf',
#     'id': '0gHGRnDOmtiVyAE4v5nlZf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ca7f97a38320728ceb4503b5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ca7f97a38320728ceb4503b5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ca7f97a38320728ceb4503b5',
#       'width': 64}],
#     'name': 'Queen Ginger',
#     'popularity': 30,
#     'type': 'artist',
#     'uri': 'spotify:artist:0gHGRnDOmtiVyAE4v5nlZf'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1UK7I2ukQwZSq2FNlWW5pz'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1UK7I2ukQwZSq2FNlWW5pz',
#     'id': '1UK7I2ukQwZSq2FNlWW5pz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d3f5add1161dddcbcd215f00',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d3f5add1161dddcbcd215f00',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d3f5add1161dddcbcd215f00',
#       'width': 64}],
#     'name': 'Marly Queen',
#     'popularity': 38,
#     'type': 'artist',
#     'uri': 'spotify:artist:1UK7I2ukQwZSq2FNlWW5pz'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3RfdshDBuwasUCL2XZuxnH'},
#     'followers': {'href': None, 'total': 238},
#     'genres': ['light music'],
#     'href': 'https://api.spotify.com/v1/artists/3RfdshDBuwasUCL2XZuxnH',
#     'id': '3RfdshDBuwasUCL2XZuxnH',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737293b5856ac0e9bf97c8694e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027293b5856ac0e9bf97c8694e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517293b5856ac0e9bf97c8694e',
#       'width': 64}],
#     'name': "Queen's Hall Light Orchestra",
#     'popularity': 26,
#     'type': 'artist',
#     'uri': 'spotify:artist:3RfdshDBuwasUCL2XZuxnH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0U4DrHIZBfvyd3olOr8EIi'},
#     'followers': {'href': None, 'total': 13077},
#     'genres': ['latin viral pop'],
#     'href': 'https://api.spotify.com/v1/artists/0U4DrHIZBfvyd3olOr8EIi',
#     'id': '0U4DrHIZBfvyd3olOr8EIi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb9536401044ee5989f5b275b4',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051749536401044ee5989f5b275b4',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1789536401044ee5989f5b275b4',
#       'width': 160}],
#     'name': 'Anabella Queen',
#     'popularity': 31,
#     'type': 'artist',
#     'uri': 'spotify:artist:0U4DrHIZBfvyd3olOr8EIi'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0tFnayGz6sZxgRf1YS5VmI'},
#     'followers': {'href': None, 'total': 696},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0tFnayGz6sZxgRf1YS5VmI',
#     'id': '0tFnayGz6sZxgRf1YS5VmI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebe5facb323ba4fc46d6a570b6',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174e5facb323ba4fc46d6a570b6',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178e5facb323ba4fc46d6a570b6',
#       'width': 160}],
#     'name': 'Queendom Come',
#     'popularity': 53,
#     'type': 'artist',
#     'uri': 'spotify:artist:0tFnayGz6sZxgRf1YS5VmI'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Queen&type=artist&market=CO&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 4629}}

# %%
df = pd.DataFrame(search.json()['artists']['items'])

# %%
df.sort_values(by='popularity', ascending=False).head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/1...
# 3  {'spotify': 'https://open.spotify.com/artist/6...
# 1  {'spotify': 'https://open.spotify.com/artist/4...
# 2  {'spotify': 'https://open.spotify.com/artist/6...
# 6  {'spotify': 'https://open.spotify.com/artist/3...
#
#                            followers  \
# 0  {'href': None, 'total': 35360491}
# 3  {'href': None, 'total': 28020911}
# 1   {'href': None, 'total': 2711924}
# 2   {'href': None, 'total': 1393043}
# 6   {'href': None, 'total': 1913172}
#
#                                               genres  \
# 0                    [classic rock, glam rock, rock]
# 3               [dance pop, pop, post-teen pop, r&b]
# 1  [alternative metal, alternative rock, blues ro...
# 2  [latin, latin hip hop, rap latina, reggaeton, ...
# 6  [dance pop, pop, pop r&b, pop rap, r&b, urban ...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/1dfeR4HaWDb...  1dfeR4HaWDbWqFHLkxsg1d
# 3  https://api.spotify.com/v1/artists/6vWDO969PvN...  6vWDO969PvNqNYHIOW5v0m
# 1  https://api.spotify.com/v1/artists/4pejUc4iciQ...  4pejUc4iciQfgdX6OKulQn
# 2  https://api.spotify.com/v1/artists/6p2442ymrT9...  6p2442ymrT9lZEuCZJdYcH
# 6  https://api.spotify.com/v1/artists/3nViOFa3kZW...  3nViOFa3kZW8OMSNOzwr98
#
#                                               images                     name  \
# 0  [{'height': 806, 'url': 'https://i.scdn.co/ima...                    Queen
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...                  Beyoncé
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Queens of the Stone Age
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...                Ivy Queen
# 6  [{'height': 640, 'url': 'https://i.scdn.co/ima...              Queen Naija
#
#    popularity    type                                    uri
# 0          90  artist  spotify:artist:1dfeR4HaWDbWqFHLkxsg1d
# 3          88  artist  spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 1          74  artist  spotify:artist:4pejUc4iciQfgdX6OKulQn
# 2          71  artist  spotify:artist:6p2442ymrT9lZEuCZJdYcH
# 6          70  artist  spotify:artist:3nViOFa3kZW8OMSNOzwr98
